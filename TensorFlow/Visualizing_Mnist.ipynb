# %%
import tensorflow as tf
# Out:
# 2026-02-18 22:51:38.510900: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-18 22:51:38.884228: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-18 22:51:41.033275: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.figure(figsize=(20,20))
print("Training Data")
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(x_train[i],cmap="grey")
    plt.axis("off")
    plt.title(str(y_train[i]))
# Out:
# Training Data

# %%
plt.figure(figsize=(20,20))

print("Testing Data")
for i in range(10):
    plt.subplot(2,10,i+1)
    plt.imshow(x_test[i],cmap="grey")
    plt.axis("off")
    plt.title(str(y_test[i]))
plt.tight_layout()
# Out:
# Testing Data

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28)
# (60000,)
