# %%
import tensorflow as tf

# Disable eager execution (required if using TF 2.x)
tf.compat.v1.disable_eager_execution()

# 1️⃣ Define placeholders
x = tf.compat.v1.placeholder(tf.float32, name="x")
y = tf.compat.v1.placeholder(tf.float32, name="y")

# 2️⃣ Define operation
z = x + y

# 3️⃣ Create a session to run the graph
with tf.compat.v1.Session() as sess:
    result = sess.run(z, feed_dict={x: 10, y: 5})
    print("Result:", result)
# Out:
# 2026-02-21 13:04:04.807360: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-21 13:04:05.333544: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-21 13:04:07.951897: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Result: 15.0
# 2026-02-21 13:04:10.041530: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771659250.047003    6120 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
