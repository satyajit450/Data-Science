# %%
import pandas as pd 

df = pd.read_csv("gurugram_train.csv")
df.drop(columns="Unnamed: 9",inplace=True)
df
df['Rate per sqft'] = (
    df['Rate per sqft']
    .astype(str)
    .str.replace(',', '', regex=True)
    .str.strip()
    .astype(float)
)
from sklearn.linear_model import LinearRegression

x= df.iloc[:,1]
y = df.iloc[:,2:]
clf = LinearRegression()
clf.fit(x,y)
# Out:
#        Area     Price  BHK_Count Rate per sqft              Status  \
# 0      1091  37800000          3         34678  Under Construction
# 1      1002  34700000          3         34665  Under Construction
# 2      1795  37600000          3         21000  Under Construction
# 3      1795  37600000          3         21000  Under Construction
# 4      2248  47200000          4         21000  Under Construction
# ...     ...       ...        ...           ...                 ...
# 15574  1200   6000000          3          5000       Ready to move
# 15575  2510  48000000          4         19124  Under Construction
# 15576  1405  25200000          3         18000  Under Construction
# 15577  1981  35600000          4         18001  Under Construction
# 15578  1324  23800000          3         18008  Under Construction
#
#                                        Property Type    Locality  \
# 0               3 BHK Apartment in Godrej Aristocrat   Sector 49
# 1               3 BHK Apartment in Godrej Aristocrat   Sector 49
# 2                   3 BHK Apartment in M3M M3M Crown  Sector 111
# 3                   3 BHK Apartment in M3M M3M Crown  Sector 111
# 4                   4 BHK Apartment in M3M M3M Crown  Sector 111
# ...                                              ...         ...
# 15574       3 BHK Apartment in Tanishq Homes Sec 105  Sector 105
# 15575               4 BHK Apartment in M3M M3M Crown  Sector 111
# 15576  3 BHK Apartment in Puri Diplomatic Residences  Sector 111
# 15577  4 BHK Apartment in Puri Diplomatic Residences  Sector 111
# 15578  3 BHK Apartment in Puri Diplomatic Residences  Sector 111
#
#                          Builder Name         RERA Approval  \
# 0                  ETHOS PRO REALTORS      Approved by RERA
# 1                  ETHOS PRO REALTORS      Approved by RERA
# 2                  ETHOS PRO REALTORS      Approved by RERA
# 3                  ETHOS PRO REALTORS      Approved by RERA
# 4                  ETHOS PRO REALTORS      Approved by RERA
# ...                               ...                   ...
# 15574                          seller  Not approved by RERA
# 15575                            home      Approved by RERA
# 15576             Property In Gurgaon      Approved by RERA
# 15577  properties for sale in Gurgaon      Approved by RERA
# 15578    PROPCURIUSE LANDBASE PVT LTD      Approved by RERA
#
#                             Socity Company Name  Flat Type
# 0                Godrej Aristocrat       Godrej  Apartment
# 1                Godrej Aristocrat       Godrej  Apartment
# 2                    M3M M3M Crown          M3M  Apartment
# 3                    M3M M3M Crown          M3M  Apartment
# 4                    M3M M3M Crown          M3M  Apartment
# ...                            ...          ...        ...
# 15574        Tanishq Homes Sec 105      Tanishq  Apartment
# 15575                M3M M3M Crown          M3M  Apartment
# 15576   Puri Diplomatic Residences         Puri  Apartment
# 15577   Puri Diplomatic Residences         Puri  Apartment
# 15578   Puri Diplomatic Residences         Puri  Apartment
#
# [15579 rows x 12 columns]

# %%
# Out:
# Area               int64
# Price              int64
# BHK_Count          int64
# Rate per sqft    float64
# Status            object
# Property Type     object
# Locality          object
# Builder Name      object
# RERA Approval     object
# Socity            object
# Company Name      object
# Flat Type         object
# dtype: object

# %%
x
# Out:
# 0        37800000
# 1        34700000
# 2        37600000
# 3        37600000
# 4        47200000
#            ...
# 15574     6000000
# 15575    48000000
# 15576    25200000
# 15577    35600000
# 15578    23800000
# Name: Price, Length: 15579, dtype: int64

# %%
y
# Out:
#        BHK_Count  Rate per sqft              Status  \
# 0              3        34678.0  Under Construction
# 1              3        34665.0  Under Construction
# 2              3        21000.0  Under Construction
# 3              3        21000.0  Under Construction
# 4              4        21000.0  Under Construction
# ...          ...            ...                 ...
# 15574          3         5000.0       Ready to move
# 15575          4        19124.0  Under Construction
# 15576          3        18000.0  Under Construction
# 15577          4        18001.0  Under Construction
# 15578          3        18008.0  Under Construction
#
#                                        Property Type    Locality  \
# 0               3 BHK Apartment in Godrej Aristocrat   Sector 49
# 1               3 BHK Apartment in Godrej Aristocrat   Sector 49
# 2                   3 BHK Apartment in M3M M3M Crown  Sector 111
# 3                   3 BHK Apartment in M3M M3M Crown  Sector 111
# 4                   4 BHK Apartment in M3M M3M Crown  Sector 111
# ...                                              ...         ...
# 15574       3 BHK Apartment in Tanishq Homes Sec 105  Sector 105
# 15575               4 BHK Apartment in M3M M3M Crown  Sector 111
# 15576  3 BHK Apartment in Puri Diplomatic Residences  Sector 111
# 15577  4 BHK Apartment in Puri Diplomatic Residences  Sector 111
# 15578  3 BHK Apartment in Puri Diplomatic Residences  Sector 111
#
#                          Builder Name         RERA Approval  \
# 0                  ETHOS PRO REALTORS      Approved by RERA
# 1                  ETHOS PRO REALTORS      Approved by RERA
# 2                  ETHOS PRO REALTORS      Approved by RERA
# 3                  ETHOS PRO REALTORS      Approved by RERA
# 4                  ETHOS PRO REALTORS      Approved by RERA
# ...                               ...                   ...
# 15574                          seller  Not approved by RERA
# 15575                            home      Approved by RERA
# 15576             Property In Gurgaon      Approved by RERA
# 15577  properties for sale in Gurgaon      Approved by RERA
# 15578    PROPCURIUSE LANDBASE PVT LTD      Approved by RERA
#
#                             Socity Company Name  Flat Type
# 0                Godrej Aristocrat       Godrej  Apartment
# 1                Godrej Aristocrat       Godrej  Apartment
# 2                    M3M M3M Crown          M3M  Apartment
# 3                    M3M M3M Crown          M3M  Apartment
# 4                    M3M M3M Crown          M3M  Apartment
# ...                            ...          ...        ...
# 15574        Tanishq Homes Sec 105      Tanishq  Apartment
# 15575                M3M M3M Crown          M3M  Apartment
# 15576   Puri Diplomatic Residences         Puri  Apartment
# 15577   Puri Diplomatic Residences         Puri  Apartment
# 15578   Puri Diplomatic Residences         Puri  Apartment
#
# [15579 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 2
#       1 clf = LinearRegression()
# ----> 2 clf.fit(x,y)
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
#     619     self,
#     620     X,
#     621     y,
#     622     accept_sparse=accept_sparse,
#     623     y_numeric=True,
#     624     multi_output=True,
#     625     force_writeable=True,
#     626 )
#     628 has_sw = sample_weight is not None
#     629 if has_sw:
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1091, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1084         else:
#    1085             msg = (
#    1086                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1087                 "Reshape your data either using array.reshape(-1, 1) if "
#    1088                 "your data has a single feature or array.reshape(1, -1) "
#    1089                 "if it contains a single sample."
#    1090             )
# -> 1091         raise ValueError(msg)
#    1093 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1094     raise ValueError(
#    1095         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1096         "Convert your data to numeric values explicitly instead."
#    1097     )
#
# ValueError: Expected a 2-dimensional container but got <class 'pandas.core.series.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.

# %%
df.dtypes
